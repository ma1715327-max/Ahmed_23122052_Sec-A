# %% [markdown]
# <a href="https://colab.research.google.com/github/ma1715327-max/Ahmed_23122052_Sec-A/blob/main/Ahmed_23122052_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from google import genai

# %%
client = genai.Client(api_key="")

# %%
MODEL = "models/gemini-3.6-flash"

# %%
response = client.models.generate_content(
    model=MODEL,
    contents="Hello"
)

print(response.text)
# Out:
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Hello! How can I help you today?

# %%
print("Gemini Chatbot (type 'exit' to quit)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye ")
        break

    response = client.models.generate_content(
        model="models/gemini-3.6-flash",
        contents=user_input
    )

    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# You: hi
# Chatbot: Hello! How can I help you today?
# You: exit
# Chatbot: Goodbye
